# %%
import pandas as pd
import numpy as np
from wbe.constants import DATA_PATH

# %%
data = pd.read_csv(DATA_PATH / "wbe/cdc_data.csv", parse_dates=True, index_col=0)

# %%
solid_mask = data["pcr_target_units"] == "copies/g dry sludge"
solid_data = data[solid_mask]
liquid_data = data[~solid_mask]

# %%
log_mask = data["pcr_target_units"] == "log10 copies/l wastewater"
data[log_mask]["pcr_target_avg_conc"]
10.0 ** data[log_mask]["pcr_target_avg_conc"]
